# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('49_KRAB-ZFP_peaks_200bp_TE.interval', sep='\t', header=None, names=['Chr', 'Start', 'End', 'Length', 'Summit', 'Tags', 'Enrichment', 'FDR', 'ZFP', 'TE'])
print(df.head())

df_zfp = df[df['ZFP'] == 'Gm21082']
TE_count = df_zfp.TE.value_counts()
ZFP_count = df_zfp.ZFP.value_counts()
print(TE_count)
Zfp_number = ZFP_count[0]
percent_TE = TE_count /Zfp_number * 100
print(percent_TE)
# Out:
#              Chr      Start  End  Length  Summit     Tags  Enrichment  FDR  \
# chr14   35781059   35781259  903     504     714  3100.00      308.80  0.0
# chr13  107074508  107074708  774     401     442  3100.00      215.94  0.0
# chr4    53377022   53377222  620     292     204  2370.57      142.70  0.0
# chr5   112555511  112555711  631     291     192  2479.05      141.54  0.0
# chr9    49196712   49196912  644     427     183  2213.85      134.12  0.0
#
#            ZFP     TE
# chr14  Gm21082      .
# chr13  Gm21082      .
# chr4   Gm21082      .
# chr5   Gm21082      .
# chr9   Gm21082  ORR1E
# IAPLTR1_Mm     939
# IAPLTR1a_Mm    916
# .              345
# IAPLTR2_Mm      38
# IAPLTR2b        20
# IAPLTR2a        11
# MMETn-int        9
# ID_B1            4
# MTD              2
# ORR1E            2
# RLTRETN_Mm       2
# RSINE1           2
# RLTR10           2
# IAPEz-int        1
# L1MC4            1
# RLTR19-int       1
# MMERGLN-int      1
# Lx6              1
# B4               1
# ETnERV2-int      1
# RLTR17           1
# RMER15           1
# Lx8              1
# B1F              1
# B4A              1
# ORR1B1           1
# Lx9              1
# MTC              1
# MER44D           1
# ORR1B1-int       1
# Lx5              1
# MLT1E1A          1
# ORR1D2           1
# MIRb             1
# L1_Rod           1
# RLTR5_Mm         1
# LTR41B           1
# MER96            1
# MIRc             1
# Name: TE, dtype: int64
# IAPLTR1_Mm     40.509060
# IAPLTR1a_Mm    39.516825
# .              14.883520
# IAPLTR2_Mm      1.639344
# IAPLTR2b        0.862813
# IAPLTR2a        0.474547
# MMETn-int       0.388266
# ID_B1           0.172563
# MTD             0.086281
# ORR1E           0.086281
# RLTRETN_Mm      0.086281
# RSINE1          0.086281
# RLTR10          0.086281
# IAPEz-int       0.043141
# L1MC4           0.043141
# RLTR19-int      0.043141
# MMERGLN-int     0.043141
# Lx6             0.043141
# B4              0.043141
# ETnERV2-int     0.043141
# RLTR17          0.043141
# RMER15          0.043141
# Lx8             0.043141
# B1F             0.043141
# B4A             0.043141
# ORR1B1          0.043141
# Lx9             0.043141
# MTC             0.043141
# MER44D          0.043141
# ORR1B1-int      0.043141
# Lx5             0.043141
# MLT1E1A         0.043141
# ORR1D2          0.043141
# MIRb            0.043141
# L1_Rod          0.043141
# RLTR5_Mm        0.043141
# LTR41B          0.043141
# MER96           0.043141
# MIRc            0.043141
# Name: TE, dtype: float64
