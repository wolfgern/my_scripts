# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
df = pd.read_csv('49_KRAB-ZFP_peaks_200bp_TE.interval', sep='\t', header=None, names=['Chr', 'Start', 'End', 'Length', 'Summit', 'Tags', 'Enrichment', 'FDR', 'ZFP', 'TE'])
unique_ZFPs = set(df.ZFP.tolist())

for zfp in unique_ZFPs:
    
    df_zfp = df[df['ZFP'] == zfp]
    TE_count = df_zfp.TE.value_counts()
    ZFP_count = df_zfp.ZFP.value_counts()
    Zfp_number = ZFP_count[0]
    percent_TE = TE_count /Zfp_number * 100
    merged = pd.concat([TE_count, percent_TE], axis=1)
    merged.columns = ['TE_count', 'TE_percentage']
    merged = merged[merged['TE_count'] >= 3]
    merged = merged[merged['TE_percentage'] >= 2]
    print(zfp)
    print(merged, '\n')
# Out:
# Zfp617
#         TE_count  TE_percentage
# ORR1A2       261      30.243337
# .            252      29.200463
# ORR1A0        63       7.300116
# ORR1A1        58       6.720742
# ORR1A3        58       6.720742
# ORR1B1        57       6.604867
# ORR1A4        33       3.823870
#
# Zfp58
#         TE_count  TE_percentage
# .             73      49.324324
# MTC           33      22.297297
# MTA_Mm        11       7.432432
# MTD            9       6.081081
# MTB            3       2.027027
#
# Zfp938
#         TE_count  TE_percentage
# .            104      51.231527
# RMER6C        22      10.837438
# RMER6A        10       4.926108
#
# Zfp46
#      TE_count  TE_percentage
# .         332      91.712707
# L2b         9       2.486188
# L2c         8       2.209945
#
# Gm14399
#            TE_count  TE_percentage
# .               141      43.788820
# IAPEz-int        86      26.708075
# L1Md_A            7       2.173913
# L1Md_F2           7       2.173913
#
# Zfp738
#            TE_count  TE_percentage
# .               138      78.409091
# MERVL-int         7       3.977273
# MMETn-int         6       3.409091
# RMER19B           5       2.840909
#
# Zfp92
#          TE_count  TE_percentage
# .             168      68.852459
# B2_Mm2          6       2.459016
# B3A             5       2.049180
# RMER17C         5       2.049180
# B3              5       2.049180
#
# Zfp429
#             TE_count  TE_percentage
# .                149      45.705521
# IAPLTR2_Mm        76      23.312883
# RLTR6_Mm          33      10.122699
# LTRIS4            22       6.748466
#
# Zfp599
#         TE_count  TE_percentage
# .            300      40.000000
# ORR1B1       126      16.800000
# ORR1D1        90      12.000000
# ORR1B2        50       6.666667
# ORR1A4        34       4.533333
# ORR1C1        31       4.133333
# ORR1C2        21       2.800000
# ORR1A2        18       2.400000
#
# Gm13139
#                TE_count  TE_percentage
# RMER16-int          110      56.122449
# MMERVK10C-int        25      12.755102
# LTRIS2               22      11.224490
# ETnERV2-int          18       9.183673
# .                    14       7.142857
#
# Zfp759
#             TE_count  TE_percentage
# .                684      61.956522
# RMER3D-int        70       6.340580
# B3                35       3.170290
#
# Gm4631
#            TE_count  TE_percentage
# .               150      40.322581
# IAPEz-int       136      36.559140
#
# Gm14420
#              TE_count  TE_percentage
# .                 261      67.968750
# L1Md_T             12       3.125000
# ETnERV3-int        10       2.604167
# L1Md_F2             9       2.343750
# IAPEz-int           9       2.343750
#
# Gm13154
#         TE_count  TE_percentage
# .           1304      70.869565
# RLTR9E       130       7.065217
#
# Zfp458
#          TE_count  TE_percentage
# RLTR25B         4           50.0
# RLTR25A         4           50.0
#
# Zfp961
#              TE_count  TE_percentage
# .                 937      57.982673
# RLTRETN_Mm        104       6.435644
# MMETn-int          99       6.126238
# ETnERV2-int        65       4.022277
# RLTR45-int         50       3.094059
# ETnERV-int         47       2.908416
#
# LOC102
#           TE_count  TE_percentage
# .              309      70.387244
# RLTR13D1        30       6.833713
#
# Gm30910
#              TE_count  TE_percentage
# MMERGLN-int        29      38.157895
# MuRRS4-int         19      25.000000
# .                  10      13.157895
# MURVY-int           7       9.210526
# RLTR6-int           6       7.894737
#
# AW146154
#                 TE_count  TE_percentage
# .                     62      36.904762
# MurERV4-int           57      33.928571
# MYSERV6-int           19      11.309524
# MurERV4_19-int        18      10.714286
#
# Gm14401
#            TE_count  TE_percentage
# .               769      49.837978
# IAPEz-int       471      30.524951
#
# Zfp953
#     TE_count  TE_percentage
# .        144      67.289720
# B3         6       2.803738
#
# Zfp661
#    TE_count  TE_percentage
# .      1129      85.855513
#
# Zfp808
#                TE_count  TE_percentage
# RMER16-int          303       47.34375
# MMERVK10C-int        74       11.56250
# ETnERV2-int          55        8.59375
# RLTR45-int           40        6.25000
# .                    37        5.78125
# ETnERV3-int          25        3.90625
# L1_Mur2              19        2.96875
#
# Zfp810
#      TE_count  TE_percentage
# .         206      83.400810
# Lx9        18       7.287449
# Lx8        10       4.048583
#
# Rex2
#            TE_count  TE_percentage
# MMETn-int        61          76.25
# .                13          16.25
#
# Gm14295
#          TE_count  TE_percentage
# .             125      48.828125
# L1Md_T         23       8.984375
# L1Md_A          8       3.125000
# L1Md_F2         7       2.734375
#
# Zfp493
#              TE_count  TE_percentage
# .                  12      42.857143
# ETnERV2-int         8      28.571429
# RMER16-int          3      10.714286
#
# Zfp595
#    TE_count  TE_percentage
# .        16      76.190476
#
# Zfp882
#      TE_count  TE_percentage
# .          16      42.105263
# Lx8        12      31.578947
#
# Gm14419
#            TE_count  TE_percentage
# IAPEz-int      2414      61.707566
# .               887      22.673824
# L1Md_T          200       5.112474
#
# Zfp534
#    TE_count  TE_percentage
# .        29      85.294118
#
# Gm21082
#              TE_count  TE_percentage
# IAPLTR1_Mm        939      40.509060
# IAPLTR1a_Mm       916      39.516825
# .                 345      14.883520
#
# Zfp935
#          TE_count  TE_percentage
# .              20      47.619048
# RLTR10          5      11.904762
# RLTR10A         3       7.142857
#
# Zfp600
#    TE_count  TE_percentage
# .         3           75.0
#
# Zfp712
#        TE_count  TE_percentage
# .           126      63.959391
# MTEa         14       7.106599
# MTE2a         9       4.568528
# MTEb          8       4.060914
# MTE2b         8       4.060914
# ORR1E         4       2.030457
#
# Zfp931
#          TE_count  TE_percentage
# .             162      46.820809
# RLTR1D         70      20.231214
# L1Md_A         10       2.890173
# L1Md_F2        10       2.890173
#
# Gm13051
#              TE_count  TE_percentage
# MMETn-int         258      43.361345
# ETnERV2-int       253      42.521008
# .                  37       6.218487
# ETnERV-int         22       3.697479
#
# Gm14443
#            TE_count  TE_percentage
# .               199      41.458333
# IAPEz-int       197      41.041667
#
# Gm13152
#           TE_count  TE_percentage
# .             4562      75.906822
# RLTR13B1       316       5.257903
# RLTR13A        136       2.262895
# RLTR13B4       128       2.129784
#
# Gm8893
#            TE_count  TE_percentage
# IAPEz-int      1314      86.447368
# .               137       9.013158
#
# Zfp273
#         TE_count  TE_percentage
# .            103      73.571429
# B3            11       7.857143
# B2_Mm2         5       3.571429
# B3A            3       2.142857
#
# Zfp874a
#          TE_count  TE_percentage
# RMER19C        87      46.031746
# .              80      42.328042
# Lx4A            7       3.703704
#
# Gm13157
#          TE_count  TE_percentage
# IAPLTR4       335      71.276596
# .              81      17.234043
#
# Zfp874b
#          TE_count  TE_percentage
# .             123      66.486486
# RMER19C         8       4.324324
# B3              6       3.243243
# B2_Mm2          5       2.702703
#
# Zfp456
#    TE_count  TE_percentage
# .        31      93.939394
#
# Zfp457
# Empty DataFrame
# Columns: [TE_count, TE_percentage]
# Index: []
#
# Gm13251
#     TE_count  TE_percentage
# .       3990      64.096386
# B3       147       2.361446
#
# Gm13150
#              TE_count  TE_percentage
# .                  43      43.434343
# IAPLTR1a_Mm        36      36.363636
# B1_Mus1             4       4.040404
# IAPLTR1_Mm          3       3.030303
#
# Gm13225
#    TE_count  TE_percentage
# .        44       69.84127

# %%
# set read numbers to calculate RPM
KAP1_ChIP = 61808121      
KAP1_Input = 115085987
H3K9me3_ChIP = 43340454
H3K9me3_Input = 46710977

# load data with KAP1 and H3K9me3 enrichment as dataframe
df = pd.read_csv('49_KRAB-ZFP_peaks_200bp_TE_KAP1_H3K9me3.interval', sep='\t', header=None, names=['Chr', 'Start', 'End', 'Enrichment', 'ZFP', 'TE', 'KAP1_ChIP', 'KAP1_Input', 'H3K9me3_ChIP', 'H3K9me3_Input'])

# generate set with unique ZFP names
unique_ZFPs = set(df.ZFP.tolist())     # 
print(unique_ZFPs)

# Load data with fisher bed values as dataframe
matrix = pd.read_csv('fisher_matrix.txt', sep='\t')

# calculate RPM values
df['KAP1_ChIP'] = df['KAP1_ChIP'] / KAP1_ChIP * 1000000
df['KAP1_Input'] = df['KAP1_Input'] / KAP1_Input * 1000000
df['H3K9me3_ChIP'] = df['H3K9me3_ChIP'] / H3K9me3_ChIP * 1000000
df['H3K9me3_Input'] = df['H3K9me3_Input'] / H3K9me3_Input * 1000000

# Iterate through unique ZFP set
for zfp in unique_ZFPs:
    
    df_zfp = df[df['ZFP'] == zfp]                    # Filter read count table for ZFP name
    matrix_zfp_sign = matrix[matrix[zfp] < 10e-5]    # Filter fisher bed table for significant overlapping TEs     
    TE_list = matrix_zfp_sign.Repeat.tolist()        # Make list of TEs that are significantly bound by ZFP
    TE_list.append('.')                              # Add '.' to list to include peaks that do not overlap with TEs
    print(TE_list)
    
    # Iterate through list of TEs that are significantly bound by ZFP
    for TE in TE_list:
        df_zfp_TE = df_zfp[df_zfp['TE'] == TE]                  # Filter read count table for TE name
        KAP1_ChIP_mean = df_zfp_TE['KAP1_ChIP'].mean()          # Calculate Mean RPM values
        KAP1_Input_mean = df_zfp_TE['KAP1_Input'].mean()
        H3K9me3_ChIP_mean = df_zfp_TE['H3K9me3_ChIP'].mean()
        H3K9me3_Input_mean = df_zfp_TE['H3K9me3_Input'].mean()
        
        KAP1_enrichment = KAP1_ChIP_mean / KAP1_Input_mean
        H3K9me3_enrichment = H3K9me3_ChIP_mean / H3K9me3_Input_mean
        print(zfp, 'binding sites in:',TE)
        print('KAP1_ChIP enrichment:', KAP1_enrichment)
        print('H3K9me3_ChIP enrichment:', H3K9me3_enrichment, '\n')
# Out:
# {'Zfp617', 'Zfp58', 'Zfp938', 'Zfp46', 'Gm14399', 'Zfp738', 'Zfp92', 'Zfp429', 'Zfp599', 'Gm13139', 'Zfp759', 'Gm4631', 'Gm14420', 'Gm13154', 'Zfp458', 'Zfp961', 'LOC102', 'Gm30910', 'AW146154', 'Gm14401', 'Zfp953', 'Zfp661', 'Zfp808', 'Zfp810', 'Rex2', 'Gm14295', 'Zfp493', 'Zfp595', 'Zfp882', 'Gm14419', 'Zfp534', 'Gm21082', 'Zfp935', 'Zfp600', 'Zfp712', 'Zfp931', 'Gm13051', 'Gm14443', 'Gm13152', 'Gm8893', 'Zfp273', 'Zfp874a', 'Gm13157', 'Zfp874b', 'Zfp456', 'Zfp457', 'Gm13251', 'Gm13150', 'Gm13225'}
# ['ORR1A0', 'ORR1A1', 'ORR1A2', 'ORR1A3', 'ORR1A4', 'ORR1B1', 'ORR1B2', 'ORR1C1', 'ORR1C2', '(CATTC)n', '.']
# Zfp617 binding sites in: ORR1A0
# KAP1_ChIP enrichment: 3.5275555334630164
# H3K9me3_ChIP enrichment: 1.461135847041265
#
# Zfp617 binding sites in: ORR1A1
# KAP1_ChIP enrichment: 2.7333821182526212
# H3K9me3_ChIP enrichment: 1.0411097276116075
#
# Zfp617 binding sites in: ORR1A2
# KAP1_ChIP enrichment: 2.780646676396391
# H3K9me3_ChIP enrichment: 0.7075654832090206
#
# Zfp617 binding sites in: ORR1A3
# KAP1_ChIP enrichment: 3.5044314776983536
# H3K9me3_ChIP enrichment: 1.0099843371369055
#
# Zfp617 binding sites in: ORR1A4
# KAP1_ChIP enrichment: 2.23845566296936
# H3K9me3_ChIP enrichment: 0.9158240280690595
#
# Zfp617 binding sites in: ORR1B1
# KAP1_ChIP enrichment: 2.558117768930692
# H3K9me3_ChIP enrichment: 1.0890737850419567
#
# Zfp617 binding sites in: ORR1B2
# KAP1_ChIP enrichment: 3.122633772645601
# H3K9me3_ChIP enrichment: 0.6928511919668795
#
# Zfp617 binding sites in: ORR1C1
# KAP1_ChIP enrichment: 2.9990218484555387
# H3K9me3_ChIP enrichment: 1.4519937016836768
#
# Zfp617 binding sites in: ORR1C2
# KAP1_ChIP enrichment: 2.95489418988218
# H3K9me3_ChIP enrichment: 0.9617011416702672
#
# Zfp617 binding sites in: (CATTC)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp617 binding sites in: .
# KAP1_ChIP enrichment: 2.6548277239698135
# H3K9me3_ChIP enrichment: 0.7603435455222545
#
# ['MTA_Mm', 'MTC', '.']
# Zfp58 binding sites in: MTA_Mm
# KAP1_ChIP enrichment: 1.8964693811268178
# H3K9me3_ChIP enrichment: 0.8382644050957309
#
# Zfp58 binding sites in: MTC
# KAP1_ChIP enrichment: 1.6551005508015866
# H3K9me3_ChIP enrichment: 1.1254046985539372
#
# Zfp58 binding sites in: .
# KAP1_ChIP enrichment: 3.3304876256831606
# H3K9me3_ChIP enrichment: 1.1103295033400078
#
# ['RMER6A', 'RMER6C', '.']
# Zfp938 binding sites in: RMER6A
# KAP1_ChIP enrichment: 3.186864281711708
# H3K9me3_ChIP enrichment: 1.4626858497078565
#
# Zfp938 binding sites in: RMER6C
# KAP1_ChIP enrichment: 3.7761815136863293
# H3K9me3_ChIP enrichment: 1.128606658612716
#
# Zfp938 binding sites in: .
# KAP1_ChIP enrichment: 1.029133034793294
# H3K9me3_ChIP enrichment: 0.5582164311960363
#
# ['L2b', '(GGA)n', '(TCC)n', 'TSS', '.']
# Zfp46 binding sites in: L2b
# KAP1_ChIP enrichment: 0.9874179422395829
# H3K9me3_ChIP enrichment: 0.49577351958518945
#
# Zfp46 binding sites in: (GGA)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp46 binding sites in: (TCC)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp46 binding sites in: TSS
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp46 binding sites in: .
# KAP1_ChIP enrichment: 2.4475430001870593
# H3K9me3_ChIP enrichment: 0.6355543376693646
#
# ['IAPEz-int', '.']
# Gm14399 binding sites in: IAPEz-int
# KAP1_ChIP enrichment: 107.3582518602062
# H3K9me3_ChIP enrichment: 11.062844796178565
#
# Gm14399 binding sites in: .
# KAP1_ChIP enrichment: 1.9563250174777667
# H3K9me3_ChIP enrichment: 4.780033878914139
#
# ['MMETn-int', '(CACAG)n', '(CAGAG)n', '(CTCTG)n', '(CTGTG)n', '.']
# Zfp738 binding sites in: MMETn-int
# KAP1_ChIP enrichment: 6.822440844661617
# H3K9me3_ChIP enrichment: 4.896148423232616
#
# Zfp738 binding sites in: (CACAG)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp738 binding sites in: (CAGAG)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp738 binding sites in: (CTCTG)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp738 binding sites in: (CTGTG)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp738 binding sites in: .
# KAP1_ChIP enrichment: 3.1188301004167407
# H3K9me3_ChIP enrichment: 2.433326201940128
#
# ['.']
# Zfp92 binding sites in: .
# KAP1_ChIP enrichment: 1.2533799706419648
# H3K9me3_ChIP enrichment: 0.5043403975713322
#
# ['LTRIS4', 'RLTR6_Mm', 'IAPLTR2_Mm', '.']
# Zfp429 binding sites in: LTRIS4
# KAP1_ChIP enrichment: 5.762649363009904
# H3K9me3_ChIP enrichment: 5.51948121277319
#
# Zfp429 binding sites in: RLTR6_Mm
# KAP1_ChIP enrichment: 7.254666514629443
# H3K9me3_ChIP enrichment: 4.805579639968974
#
# Zfp429 binding sites in: IAPLTR2_Mm
# KAP1_ChIP enrichment: 12.594334075294185
# H3K9me3_ChIP enrichment: 12.122592935230573
#
# Zfp429 binding sites in: .
# KAP1_ChIP enrichment: 4.706909379851595
# H3K9me3_ChIP enrichment: 1.0020217372443805
#
# ['ORR1A2', 'ORR1A4', 'ORR1B1', 'ORR1B2', 'ORR1C1', 'ORR1C2', 'ORR1D1', 'TSS', '.']
# Zfp599 binding sites in: ORR1A2
# KAP1_ChIP enrichment: 1.7643314000896286
# H3K9me3_ChIP enrichment: 0.7151548128920855
#
# Zfp599 binding sites in: ORR1A4
# KAP1_ChIP enrichment: 1.1852203096841876
# H3K9me3_ChIP enrichment: 1.01498588855558
#
# Zfp599 binding sites in: ORR1B1
# KAP1_ChIP enrichment: 1.4390378707314233
# H3K9me3_ChIP enrichment: 0.8818106079578457
#
# Zfp599 binding sites in: ORR1B2
# KAP1_ChIP enrichment: 1.5487833279202343
# H3K9me3_ChIP enrichment: 1.303455091440065
#
# Zfp599 binding sites in: ORR1C1
# KAP1_ChIP enrichment: 2.2486763973221335
# H3K9me3_ChIP enrichment: 1.1711751259766072
#
# Zfp599 binding sites in: ORR1C2
# KAP1_ChIP enrichment: 1.320109224149408
# H3K9me3_ChIP enrichment: 0.9807693539620049
#
# Zfp599 binding sites in: ORR1D1
# KAP1_ChIP enrichment: 1.651140980105888
# H3K9me3_ChIP enrichment: 1.1259511135336262
#
# Zfp599 binding sites in: TSS
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp599 binding sites in: .
# KAP1_ChIP enrichment: 2.309747809205596
# H3K9me3_ChIP enrichment: 0.561237977887904
#
# ['LTRIS2', 'ETnERV2-int', 'MMERVK10C-int', 'RMER16-int', '.']
# Gm13139 binding sites in: LTRIS2
# KAP1_ChIP enrichment: 4.5506347579420785
# H3K9me3_ChIP enrichment: 5.655718618870377
#
# Gm13139 binding sites in: ETnERV2-int
# KAP1_ChIP enrichment: 7.954827022290125
# H3K9me3_ChIP enrichment: 5.339403681212651
#
# Gm13139 binding sites in: MMERVK10C-int
# KAP1_ChIP enrichment: 12.21826717452919
# H3K9me3_ChIP enrichment: 5.573392008439818
#
# Gm13139 binding sites in: RMER16-int
# KAP1_ChIP enrichment: 11.192825217776852
# H3K9me3_ChIP enrichment: 5.59730846895229
#
# Gm13139 binding sites in: .
# KAP1_ChIP enrichment: 5.040819548258826
# H3K9me3_ChIP enrichment: 2.3413592004398005
#
# ['RMER3D-int', '(TCC)n', '.']
# Zfp759 binding sites in: RMER3D-int
# KAP1_ChIP enrichment: 1.2438769555741618
# H3K9me3_ChIP enrichment: 1.2073970370892861
#
# Zfp759 binding sites in: (TCC)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp759 binding sites in: .
# KAP1_ChIP enrichment: 1.423414402186962
# H3K9me3_ChIP enrichment: 0.7746810744725234
#
# ['IAPEz-int', '.']
# Gm4631 binding sites in: IAPEz-int
# KAP1_ChIP enrichment: 80.89521454246156
# H3K9me3_ChIP enrichment: 10.856121192369928
#
# Gm4631 binding sites in: .
# KAP1_ChIP enrichment: 1.9006310867703888
# H3K9me3_ChIP enrichment: 3.622092704233647
#
# ['HAL1-2a_MD', 'ETnERV3-int', '(CAG)n', '(CTG)n', '.']
# Gm14420 binding sites in: HAL1-2a_MD
# KAP1_ChIP enrichment: 1.207223066587421
# H3K9me3_ChIP enrichment: 1.3390457380100635
#
# Gm14420 binding sites in: ETnERV3-int
# KAP1_ChIP enrichment: 1.5503901077916904
# H3K9me3_ChIP enrichment: 1.7962808680622806
#
# Gm14420 binding sites in: (CAG)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Gm14420 binding sites in: (CTG)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Gm14420 binding sites in: .
# KAP1_ChIP enrichment: 1.4069921753798837
# H3K9me3_ChIP enrichment: 1.44106128067019
#
# ['ETnERV3-int', 'IAPEY2_LTR', 'IAPEY_LTR', 'MMTV-int', 'RLTR9D', 'RLTR9E', 'RMER19B', '(CAG)n', 'TSS', '.']
# Gm13154 binding sites in: ETnERV3-int
# KAP1_ChIP enrichment: 5.741648984344301
# H3K9me3_ChIP enrichment: 5.09152715016274
#
# Gm13154 binding sites in: IAPEY2_LTR
# KAP1_ChIP enrichment: 17.97825015528649
# H3K9me3_ChIP enrichment: 5.308412117557187
#
# Gm13154 binding sites in: IAPEY_LTR
# KAP1_ChIP enrichment: 9.209631473967917
# H3K9me3_ChIP enrichment: 5.687501350924907
#
# Gm13154 binding sites in: MMTV-int
# KAP1_ChIP enrichment: 1.7909198708101137
# H3K9me3_ChIP enrichment: 3.391800933223481
#
# Gm13154 binding sites in: RLTR9D
# KAP1_ChIP enrichment: 7.8042588471824805
# H3K9me3_ChIP enrichment: 2.1318498214365524
#
# Gm13154 binding sites in: RLTR9E
# KAP1_ChIP enrichment: 6.349905049175392
# H3K9me3_ChIP enrichment: 2.8008777639525477
#
# Gm13154 binding sites in: RMER19B
# KAP1_ChIP enrichment: 1.5614567038483385
# H3K9me3_ChIP enrichment: 0.786240970119064
#
# Gm13154 binding sites in: (CAG)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Gm13154 binding sites in: TSS
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Gm13154 binding sites in: .
# KAP1_ChIP enrichment: 1.9277413272715702
# H3K9me3_ChIP enrichment: 0.6411921208831262
# ['RLTR25A', 'RLTR25B', '.']
# Zfp458 binding sites in: RLTR25A
# KAP1_ChIP enrichment: 7.335104713779759
# H3K9me3_ChIP enrichment: 2.9393686931928227
#
# Zfp458 binding sites in: RLTR25B
# KAP1_ChIP enrichment: 3.9373290446803373
# H3K9me3_ChIP enrichment: 1.7117500036828794
#
# Zfp458 binding sites in: .
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# ['ETnERV-int', 'ETnERV2-int', 'ETnERV3-int', 'MMETn-int', 'RLTR3_Mm', 'RLTR45-int', 'RLTR45', 'RLTR9E', 'RLTRETN_Mm', 'TSS', '.']
# Zfp961 binding sites in: ETnERV-int
# KAP1_ChIP enrichment: 8.059918000734731
# H3K9me3_ChIP enrichment: 6.666369945696658
#
# Zfp961 binding sites in: ETnERV2-int
# KAP1_ChIP enrichment: 7.710331756886551
# H3K9me3_ChIP enrichment: 7.956810920983462
#
# Zfp961 binding sites in: ETnERV3-int
# KAP1_ChIP enrichment: 9.834862780926715
# H3K9me3_ChIP enrichment: 4.311074083349473
#
# Zfp961 binding sites in: MMETn-int
# KAP1_ChIP enrichment: 9.880245275880466
# H3K9me3_ChIP enrichment: 6.160067482528703
#
# Zfp961 binding sites in: RLTR3_Mm
# KAP1_ChIP enrichment: 2.3430017172284963
# H3K9me3_ChIP enrichment: 6.46661112502421
#
# Zfp961 binding sites in: RLTR45-int
# KAP1_ChIP enrichment: 4.963505233572484
# H3K9me3_ChIP enrichment: 6.825867298636667
#
# Zfp961 binding sites in: RLTR45
# KAP1_ChIP enrichment: 6.474958686759024
# H3K9me3_ChIP enrichment: 6.25840584258972
#
# Zfp961 binding sites in: RLTR9E
# KAP1_ChIP enrichment: 9.100604655812866
# H3K9me3_ChIP enrichment: 5.587815254187586
#
# Zfp961 binding sites in: RLTRETN_Mm
# KAP1_ChIP enrichment: 6.867683339942185
# H3K9me3_ChIP enrichment: 5.838477689399909
#
# Zfp961 binding sites in: TSS
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp961 binding sites in: .
# KAP1_ChIP enrichment: 3.32370417326474
# H3K9me3_ChIP enrichment: 1.7929798925007518
#
# ['RLTR13D1', 'RLTR13D6', 'RLTR9E', 'TSS', '.']
# LOC102 binding sites in: RLTR13D1
# KAP1_ChIP enrichment: 3.0219151450086352
# H3K9me3_ChIP enrichment: 0.8164913036646726
#
# LOC102 binding sites in: RLTR13D6
# KAP1_ChIP enrichment: 3.7743002425374015
# H3K9me3_ChIP enrichment: 1.7186038575514793
#
# LOC102 binding sites in: RLTR9E
# KAP1_ChIP enrichment: 5.48621499540258
# H3K9me3_ChIP enrichment: 1.65033304753222
#
# LOC102 binding sites in: TSS
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# LOC102 binding sites in: .
# KAP1_ChIP enrichment: 2.1537243851808907
# H3K9me3_ChIP enrichment: 0.5053583896002332
#
# ['MMERGLN-int', 'MURVY-int', 'MuRRS4-int', 'RLTR6-int', '.']
# Gm30910 binding sites in: MMERGLN-int
# KAP1_ChIP enrichment: 15.684451838487579
# H3K9me3_ChIP enrichment: 12.179594637733572
#
# Gm30910 binding sites in: MURVY-int
# KAP1_ChIP enrichment: 9.765533436046063
# H3K9me3_ChIP enrichment: 5.6849328571641395
#
# Gm30910 binding sites in: MuRRS4-int
# KAP1_ChIP enrichment: 8.6162587497612
# H3K9me3_ChIP enrichment: 8.66850380200378
#
# Gm30910 binding sites in: RLTR6-int
# KAP1_ChIP enrichment: 9.450468003515663
# H3K9me3_ChIP enrichment: 12.411721352869048
#
# Gm30910 binding sites in: .
# KAP1_ChIP enrichment: 5.321852568933824
# H3K9me3_ChIP enrichment: 2.7521589014239947
#
# ['MYSERV6-int', 'MurERV4-int', 'MurERV4_19-int', '.']
# AW146154 binding sites in: MYSERV6-int
# KAP1_ChIP enrichment: 1.1756348346706529
# H3K9me3_ChIP enrichment: 0.7614668897220536
#
# AW146154 binding sites in: MurERV4-int
# KAP1_ChIP enrichment: 0.8213337018175538
# H3K9me3_ChIP enrichment: 0.6582086323685358
#
# AW146154 binding sites in: MurERV4_19-int
# KAP1_ChIP enrichment: 0.944993970499966
# H3K9me3_ChIP enrichment: 0.974420854455703
#
# AW146154 binding sites in: .
# KAP1_ChIP enrichment: 1.0925159208077337
# H3K9me3_ChIP enrichment: 0.50424170082034
#
# ['IAPEz-int', 'RLTR13C2', 'RLTR9E', 'TSS', '.']
# Gm14401 binding sites in: IAPEz-int
# KAP1_ChIP enrichment: 6.431149995984103
# H3K9me3_ChIP enrichment: 11.36634592658204
#
# Gm14401 binding sites in: RLTR13C2
# KAP1_ChIP enrichment: 5.63370764407463
# H3K9me3_ChIP enrichment: 1.5693822320965187
#
# Gm14401 binding sites in: RLTR9E
# KAP1_ChIP enrichment: 7.115246137478138
# H3K9me3_ChIP enrichment: 1.2140381039317483
#
# Gm14401 binding sites in: TSS
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Gm14401 binding sites in: .
# KAP1_ChIP enrichment: 1.9870517576121658
# H3K9me3_ChIP enrichment: 4.773670162454718
#
# ['.']
# Zfp953 binding sites in: .
# KAP1_ChIP enrichment: 1.0691841893446974
# H3K9me3_ChIP enrichment: 0.4561204661564284
#
# ['MamGypLTR3', 'ORR1D2', '(CACAG)n', '(CTGTG)n', 'TSS', '.']
# Zfp661 binding sites in: MamGypLTR3
# KAP1_ChIP enrichment: 2.3698030613749994
# H3K9me3_ChIP enrichment: 0.5645454156767168
#
# Zfp661 binding sites in: ORR1D2
# KAP1_ChIP enrichment: 6.783843382598002
# H3K9me3_ChIP enrichment: 1.2159439722267744
#
# Zfp661 binding sites in: (CACAG)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp661 binding sites in: (CTGTG)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp661 binding sites in: TSS
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp661 binding sites in: .
# KAP1_ChIP enrichment: 2.610136217898708
# H3K9me3_ChIP enrichment: 0.5758339516184268
#
# ['L1_Mur2', 'ETnERV2-int', 'ETnERV3-int', 'IAPEY3-int', 'MMERVK10C-int', 'RLTR45-int', 'RMER16-int', '.']
# Zfp808 binding sites in: L1_Mur2
# KAP1_ChIP enrichment: 3.703287482418549
# H3K9me3_ChIP enrichment: 1.2351953834315905
#
# Zfp808 binding sites in: ETnERV2-int
# KAP1_ChIP enrichment: 32.85066826709802
# H3K9me3_ChIP enrichment: 4.34699970071072
#
# Zfp808 binding sites in: ETnERV3-int
# KAP1_ChIP enrichment: 27.965629258616232
# H3K9me3_ChIP enrichment: 4.320130961675839
#
# Zfp808 binding sites in: IAPEY3-int
# KAP1_ChIP enrichment: 30.21775490912014
# H3K9me3_ChIP enrichment: 4.829999667456355
#
# Zfp808 binding sites in: MMERVK10C-int
# KAP1_ChIP enrichment: 30.05041937549128
# H3K9me3_ChIP enrichment: 4.858422494455363
#
# Zfp808 binding sites in: RLTR45-int
# KAP1_ChIP enrichment: 37.333834963540745
# H3K9me3_ChIP enrichment: 3.778244702261337
#
# Zfp808 binding sites in: RMER16-int
# KAP1_ChIP enrichment: 28.973513124872955
# H3K9me3_ChIP enrichment: 4.3542396375851755
#
# Zfp808 binding sites in: .
# KAP1_ChIP enrichment: 4.583902050287792
# H3K9me3_ChIP enrichment: 1.0428138661075075
#
# ['Lx9', 'CT-rich', 'GA-rich', '(CAGG)n', '(CCTG)n', 'TSS', '.']
# Zfp810 binding sites in: Lx9
# KAP1_ChIP enrichment: 0.6887842231232212
# H3K9me3_ChIP enrichment: 0.4815561476081858
#
# Zfp810 binding sites in: CT-rich
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp810 binding sites in: GA-rich
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp810 binding sites in: (CAGG)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp810 binding sites in: (CCTG)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp810 binding sites in: TSS
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp810 binding sites in: .
# KAP1_ChIP enrichment: 4.111821222299726
# H3K9me3_ChIP enrichment: 0.9304782104995403
#
# ['MMETn-int', '.']
# Rex2 binding sites in: MMETn-int
# KAP1_ChIP enrichment: 4.354336800644015
# H3K9me3_ChIP enrichment: 6.388565818342882
#
# Rex2 binding sites in: .
# KAP1_ChIP enrichment: 1.6235068826520485
# H3K9me3_ChIP enrichment: 2.167512247461819
#
# ['L1Md_T', '.']
# Gm14295 binding sites in: L1Md_T
# KAP1_ChIP enrichment: 3.4306493437419863
# H3K9me3_ChIP enrichment: 1.4724443172003476
#
# Gm14295 binding sites in: .
# KAP1_ChIP enrichment: 1.88199079445421
# H3K9me3_ChIP enrichment: 3.7800567464405503
#
# ['ETnERV2-int', '.']
# Zfp493 binding sites in: ETnERV2-int
# KAP1_ChIP enrichment: 2.634368376692525
# H3K9me3_ChIP enrichment: 2.669926562983481
#
# Zfp493 binding sites in: .
# KAP1_ChIP enrichment: 2.5872974453300963
# H3K9me3_ChIP enrichment: 0.5705833345609596
#
# ['.']
# Zfp595 binding sites in: .
# KAP1_ChIP enrichment: 0.9402118227944657
# H3K9me3_ChIP enrichment: 0.60402411607369
#
# ['Lx8', '.']
# Zfp882 binding sites in: Lx8
# KAP1_ChIP enrichment: 2.7683527069955107
# H3K9me3_ChIP enrichment: 1.1421129101410918
#
# Zfp882 binding sites in: .
# KAP1_ChIP enrichment: 1.28708856197128
# H3K9me3_ChIP enrichment: 0.6351135926363063
#
# ['L1Md_Gf', 'L1Md_T', 'IAPEY3-int', 'IAPEy-int', 'IAPEz-int', 'IAPLTR1_Mm', 'IAPLTR1a_Mm', 'IAPLTR4_I', 'TSS', '.']
# Gm14419 binding sites in: L1Md_Gf
# KAP1_ChIP enrichment: 7.038315092283746
# H3K9me3_ChIP enrichment: 3.4353871601691104
#
# Gm14419 binding sites in: L1Md_T
# KAP1_ChIP enrichment: 6.618224439323711
# H3K9me3_ChIP enrichment: 2.503566459861803
#
# Gm14419 binding sites in: IAPEY3-int
# KAP1_ChIP enrichment: 12.124573802383711
# H3K9me3_ChIP enrichment: 9.006010927545134
#
# Gm14419 binding sites in: IAPEy-int
# KAP1_ChIP enrichment: 11.857051942945784
# H3K9me3_ChIP enrichment: 8.242652208657617
#
# Gm14419 binding sites in: IAPEz-int
# KAP1_ChIP enrichment: 50.453727957115696
# H3K9me3_ChIP enrichment: 10.325890506778201
#
# Gm14419 binding sites in: IAPLTR1_Mm
# KAP1_ChIP enrichment: 20.20762300397286
# H3K9me3_ChIP enrichment: 11.622422697678646
#
# Gm14419 binding sites in: IAPLTR1a_Mm
# KAP1_ChIP enrichment: 22.01897930036134
# H3K9me3_ChIP enrichment: 10.685305049444764
#
# Gm14419 binding sites in: IAPLTR4_I
# KAP1_ChIP enrichment: 13.139997120241308
# H3K9me3_ChIP enrichment: 7.911089267059355
#
# Gm14419 binding sites in: TSS
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Gm14419 binding sites in: .
# KAP1_ChIP enrichment: 2.5706493557118795
# H3K9me3_ChIP enrichment: 2.878110474543246
#
# ['(CATTC)n', '.']
# Zfp534 binding sites in: (CATTC)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp534 binding sites in: .
# KAP1_ChIP enrichment: 2.7500132228703285
# H3K9me3_ChIP enrichment: 1.8616001723554545
#
# ['IAPLTR1_Mm', 'IAPLTR1a_Mm', 'IAPLTR2_Mm', 'IAPLTR2a', 'IAPLTR2b', 'CT-rich', 'GA-rich', '(CAGG)n', '(CCTG)n', '(TCTCTG)n', '.']
# Gm21082 binding sites in: IAPLTR1_Mm
# KAP1_ChIP enrichment: 12.445704676723484
# H3K9me3_ChIP enrichment: 11.085579048872875
#
# Gm21082 binding sites in: IAPLTR1a_Mm
# KAP1_ChIP enrichment: 29.274460662181152
# H3K9me3_ChIP enrichment: 13.198664964361363
#
# Gm21082 binding sites in: IAPLTR2_Mm
# KAP1_ChIP enrichment: 17.315396369051427
# H3K9me3_ChIP enrichment: 13.379928939606016
#
# Gm21082 binding sites in: IAPLTR2a
# KAP1_ChIP enrichment: 15.952120440291608
# H3K9me3_ChIP enrichment: 12.340449563587866
#
# Gm21082 binding sites in: IAPLTR2b
# KAP1_ChIP enrichment: 9.751108515110218
# H3K9me3_ChIP enrichment: 6.048060243145621
#
# Gm21082 binding sites in: CT-rich
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
# Gm21082 binding sites in: GA-rich
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Gm21082 binding sites in: (CAGG)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Gm21082 binding sites in: (CCTG)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Gm21082 binding sites in: (TCTCTG)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Gm21082 binding sites in: .
# KAP1_ChIP enrichment: 3.9506352172396997
# H3K9me3_ChIP enrichment: 0.9477066831498583
#
# ['RLTR10', '.']
# Zfp935 binding sites in: RLTR10
# KAP1_ChIP enrichment: 3.578508417455774
# H3K9me3_ChIP enrichment: 5.963652481966771
#
# Zfp935 binding sites in: .
# KAP1_ChIP enrichment: 2.126099909673315
# H3K9me3_ChIP enrichment: 1.5088759291723162
#
# ['.']
# Zfp600 binding sites in: .
# KAP1_ChIP enrichment: 1.2281198236001136
# H3K9me3_ChIP enrichment: 4.926941809542256
#
# ['MTE2a', 'MTE2b', 'MTEa', 'MTEb', 'TSS', '.']
# Zfp712 binding sites in: MTE2a
# KAP1_ChIP enrichment: 2.976462760611248
# H3K9me3_ChIP enrichment: 0.750588791297453
#
# Zfp712 binding sites in: MTE2b
# KAP1_ChIP enrichment: 1.679440264783963
# H3K9me3_ChIP enrichment: 0.7461474375027933
#
# Zfp712 binding sites in: MTEa
# KAP1_ChIP enrichment: 2.575287051060678
# H3K9me3_ChIP enrichment: 0.9651658395558523
#
# Zfp712 binding sites in: MTEb
# KAP1_ChIP enrichment: 1.7548233357869345
# H3K9me3_ChIP enrichment: 0.7519315261656058
#
# Zfp712 binding sites in: TSS
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp712 binding sites in: .
# KAP1_ChIP enrichment: 4.338328191339162
# H3K9me3_ChIP enrichment: 0.8518110179770447
#
# ['RLTR1D', 'TSS', '.']
# Zfp931 binding sites in: RLTR1D
# KAP1_ChIP enrichment: 7.053675924507071
# H3K9me3_ChIP enrichment: 3.601324081822424
#
# Zfp931 binding sites in: TSS
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp931 binding sites in: .
# KAP1_ChIP enrichment: 1.5783852147546862
# H3K9me3_ChIP enrichment: 4.478165526910297
#
# ['ETnERV-int', 'ETnERV2-int', 'ETnERV3-int', 'MMETn-int', 'RLTR45-int', '.']
# Gm13051 binding sites in: ETnERV-int
# KAP1_ChIP enrichment: 21.866110484068663
# H3K9me3_ChIP enrichment: 8.142133615401633
#
# Gm13051 binding sites in: ETnERV2-int
# KAP1_ChIP enrichment: 18.755956183985454
# H3K9me3_ChIP enrichment: 8.370802895981276
#
# Gm13051 binding sites in: ETnERV3-int
# KAP1_ChIP enrichment: 17.408467239154035
# H3K9me3_ChIP enrichment: 7.884727599810221
#
# Gm13051 binding sites in: MMETn-int
# KAP1_ChIP enrichment: 20.733081960483137
# H3K9me3_ChIP enrichment: 8.913561972762261
#
# Gm13051 binding sites in: RLTR45-int
# KAP1_ChIP enrichment: 17.226556753241002
# H3K9me3_ChIP enrichment: 8.660639899585997
#
# Gm13051 binding sites in: .
# KAP1_ChIP enrichment: 5.4984884070254045
# H3K9me3_ChIP enrichment: 1.1485311004883068
#
# ['IAPEz-int', '.']
# Gm14443 binding sites in: IAPEz-int
# KAP1_ChIP enrichment: 11.173085591548272
# H3K9me3_ChIP enrichment: 17.792593419326057
#
# Gm14443 binding sites in: .
# KAP1_ChIP enrichment: 2.868742154546602
# H3K9me3_ChIP enrichment: 1.1394121078225312
#
# ['RLTR23', 'RLTR13A', 'RLTR13A2', 'RLTR13A3', 'RLTR13B1', 'RLTR13B2', 'RLTR13B3', 'RLTR13B4', 'RLTR13C2', 'RLTR13D1', 'RLTR13D6', 'GC_rich', '(CCG)n', '(CGG)n', 'TSS', '.']
# Gm13152 binding sites in: RLTR23
# KAP1_ChIP enrichment: 3.749186910169261
# H3K9me3_ChIP enrichment: 0.8280416684482224
#
# Gm13152 binding sites in: RLTR13A
# KAP1_ChIP enrichment: 8.350412175040963
# H3K9me3_ChIP enrichment: 3.706167579104657
#
# Gm13152 binding sites in: RLTR13A2
# KAP1_ChIP enrichment: 9.978563604861158
# H3K9me3_ChIP enrichment: 4.336334283056597
#
# Gm13152 binding sites in: RLTR13A3
# KAP1_ChIP enrichment: 9.620271951534221
# H3K9me3_ChIP enrichment: 3.6209498261375335
#
# Gm13152 binding sites in: RLTR13B1
# KAP1_ChIP enrichment: 4.225799264310285
# H3K9me3_ChIP enrichment: 4.0710668077008165
#
# Gm13152 binding sites in: RLTR13B2
# KAP1_ChIP enrichment: 10.449224854520446
# H3K9me3_ChIP enrichment: 3.896314849207005
#
# Gm13152 binding sites in: RLTR13B3
# KAP1_ChIP enrichment: 2.190846717898743
# H3K9me3_ChIP enrichment: 2.622175280366957
#
# Gm13152 binding sites in: RLTR13B4
# KAP1_ChIP enrichment: 2.192841672827403
# H3K9me3_ChIP enrichment: 2.5160717070082317
#
# Gm13152 binding sites in: RLTR13C2
# KAP1_ChIP enrichment: 2.1676352260851903
# H3K9me3_ChIP enrichment: 1.938779126869456
#
# Gm13152 binding sites in: RLTR13D1
# KAP1_ChIP enrichment: 1.7268638153628078
# H3K9me3_ChIP enrichment: 1.5753717923626949
#
# Gm13152 binding sites in: RLTR13D6
# KAP1_ChIP enrichment: 2.8974761546076
# H3K9me3_ChIP enrichment: 2.103548207645474
#
# Gm13152 binding sites in: GC_rich
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Gm13152 binding sites in: (CCG)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Gm13152 binding sites in: (CGG)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Gm13152 binding sites in: TSS
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Gm13152 binding sites in: .
# KAP1_ChIP enrichment: 4.010100104372439
# H3K9me3_ChIP enrichment: 0.6125960023642435
#
# ['IAPEz-int', '.']
# Gm8893 binding sites in: IAPEz-int
# KAP1_ChIP enrichment: 8.56544352194321
# H3K9me3_ChIP enrichment: 17.13583081133283
#
# Gm8893 binding sites in: .
# KAP1_ChIP enrichment: 2.005735511008122
# H3K9me3_ChIP enrichment: 4.557125457175204
#
# ['TSS', '.']
# Zfp273 binding sites in: TSS
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp273 binding sites in: .
# KAP1_ChIP enrichment: 3.401554054082484
# H3K9me3_ChIP enrichment: 0.47945590272765165
#
# ['RMER19C', 'TSS', '.']
# Zfp874a binding sites in: RMER19C
# KAP1_ChIP enrichment: 2.241281995877148
# H3K9me3_ChIP enrichment: 2.634839504258428
#
# Zfp874a binding sites in: TSS
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp874a binding sites in: .
# KAP1_ChIP enrichment: 3.2422914415989097
# H3K9me3_ChIP enrichment: 0.7020327062335152
#
# ['IAPEY3_LTR', 'IAPLTR3', 'IAPLTR4', '.']
# Gm13157 binding sites in: IAPEY3_LTR
# KAP1_ChIP enrichment: 2.3781828458918834
# H3K9me3_ChIP enrichment: 3.0064069265463433
#
# Gm13157 binding sites in: IAPLTR3
# KAP1_ChIP enrichment: 4.220506404544046
# H3K9me3_ChIP enrichment: 7.903635819474035
#
# Gm13157 binding sites in: IAPLTR4
# KAP1_ChIP enrichment: 6.3061955714062785
# H3K9me3_ChIP enrichment: 7.587104484922914
#
# Gm13157 binding sites in: .
# KAP1_ChIP enrichment: 2.3645043719097534
# H3K9me3_ChIP enrichment: 0.748546625404732
#
# ['RMER19C', '.']
# Zfp874b binding sites in: RMER19C
# KAP1_ChIP enrichment: 3.103313532752974
# H3K9me3_ChIP enrichment: 4.372660855968751
#
# Zfp874b binding sites in: .
# KAP1_ChIP enrichment: 1.2131310275515987
# H3K9me3_ChIP enrichment: 0.5313549394148299
#
# ['TSS', '.']
# Zfp456 binding sites in: TSS
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Zfp456 binding sites in: .
# KAP1_ChIP enrichment: 3.5095654861315455
# H3K9me3_ChIP enrichment: 0.5388842604186842
#
# ['.']
# Zfp457 binding sites in: .
# KAP1_ChIP enrichment: 3.7239762393035694
# H3K9me3_ChIP enrichment: 1.0777685208373684
#
# ['RLTR10', 'RMER16-int', 'RMER10A', 'TSS', '.']
# Gm13251 binding sites in: RLTR10
# KAP1_ChIP enrichment: 2.3243610084243755
# H3K9me3_ChIP enrichment: 4.742181491684421
#
# Gm13251 binding sites in: RMER16-int
# KAP1_ChIP enrichment: 11.816463067020942
# H3K9me3_ChIP enrichment: 5.0275098052933895
#
# Gm13251 binding sites in: RMER10A
# KAP1_ChIP enrichment: 1.4262911203513668
# H3K9me3_ChIP enrichment: 0.5632209689537214
#
# Gm13251 binding sites in: TSS
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Gm13251 binding sites in: .
# KAP1_ChIP enrichment: 0.9323289993784084
# H3K9me3_ChIP enrichment: 0.5244198852191005
#
# ['IAPLTR1a_Mm', '.']
# Gm13150 binding sites in: IAPLTR1a_Mm
# KAP1_ChIP enrichment: 27.47187336534891
# H3K9me3_ChIP enrichment: 14.173394246628403
#
# Gm13150 binding sites in: .
# KAP1_ChIP enrichment: 5.2573782201932735
# H3K9me3_ChIP enrichment: 1.3096140747384306
#
# ['(ACTG)n', '(CAGT)n', '.']
# Gm13225 binding sites in: (ACTG)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Gm13225 binding sites in: (CAGT)n
# KAP1_ChIP enrichment: nan
# H3K9me3_ChIP enrichment: nan
#
# Gm13225 binding sites in: .
# KAP1_ChIP enrichment: 2.2544250776053003
# H3K9me3_ChIP enrichment: 1.468264361720473
